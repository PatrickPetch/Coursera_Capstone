# %% [markdown]
# # Week 3 Assignment Jupyter Notebook
# ### Phumrapee Pisutsin
#
# Dear all pear graders, <br>
# I have labelled each part clearly :)

# %% [markdown]
# # Beginning of Part 1

# %% [markdown]
# Libraries used are firstly imported

# %%
#import libraries

import pandas as pd
import numpy as np
import folium
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

# %% [markdown]
# The following url is the url of the table from Wikipedia

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# Use Pandas read_html method to get the table and store in the dataframe *toronto_df*
#
# Scrape the data from the url

# %%
toronto_df = pd.read_html(url, header=0)[0]
toronto_df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Get the index of the row which the value of Borough is 'Not assigned'

# %%
indexNames = toronto_df[toronto_df['Borough'] == 'Not assigned'].index
print(indexNames)
# Out:
# Int64Index([  0,   1,   7,  10,  15,  16,  19,  24,  25,  28,  29,  33,  34,
#              35,  37,  38,  42,  43,  44,  51,  52,  53,  60,  61,  62,  69,
#              70,  71,  78,  79,  87,  88,  96,  97, 101, 105, 106, 110, 115,
#             118, 119, 123, 124, 125, 127, 128, 131, 132, 133, 134, 136, 137,
#             140, 141, 145, 146, 149, 150, 154, 155, 158, 159, 161, 162, 163,
#             164, 166, 167, 170, 171, 172, 173, 174, 175, 176, 177, 179],
#            dtype='int64')

# %% [markdown]
# Drop all the row that the value of Borough is 'Not assigned'

# %%
toronto_df = toronto_df.drop(indexNames)
toronto_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Check the total number of postal code and compare it with unique number of postal code

# %%
toronto_df.shape
# Out:
# (103, 3)

# %%
len(list(toronto_df['Postal Code'].unique()))
# Out:
# 103

# %% [markdown]
# Since the number of the unique postal code is equal to the total number of postal code, this means there is no repeated postal code row. So the dataframe is not needed to be cleaned

# %% [markdown]
# Check if there is no neighborhood with value 'NaN' or 'Not assigned'

# %%
toronto_df[toronto_df['Neighborhood'] == np.NaN]
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %%
toronto_df[toronto_df['Neighborhood'] == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# Since there is no neighborhood with value 'NaN' or 'Not assigned' so the data is not needed to be cleaned

# %% [markdown]
# Reset the index of all rows and order of all columns

# %%
toronto_df = toronto_df.reset_index()
toronto_df = toronto_df[['Postal Code', 'Borough', 'Neighborhood']]
toronto_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Create the new dataframe *toronto_df1* to store the same data but use the postal code of each row as index

# %%
toronto_df1 = toronto_df.set_index(['Postal Code'])
toronto_df1.head()
# Out:
#                       Borough                                 Neighborhood
# Postal Code
# M3A                North York                                    Parkwoods
# M4A                North York                             Victoria Village
# M5A          Downtown Toronto                    Regent Park, Harbourfront
# M6A                North York             Lawrence Manor, Lawrence Heights
# M7A          Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Check that there is no cell with the value *NaN* in all columns

# %%
toronto_df.isnull().sum()
# Out:
# Postal Code     0
# Borough         0
# Neighborhood    0
# dtype: int64

# %% [markdown]
# As there is no NaN so the dataframe is ready to be used now

# %% [markdown]
# Print the shape (No. of rows and columns) of the dataframe

# %%
toronto_df.shape
# Out:
# (103, 3)

# %% [markdown]
# # End of Part 1

# %% [markdown]
# # Beginning of Part 2

# %% [markdown]
# As the service cannot be used, so the data of each postal code is imported from the given csv format file

# %%
location_df = pd.read_csv('https://cocl.us/Geospatial_data')
location_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Set index to be Postal Code so that this dataframe can be used to join the previous dataframe

# %%
location_df1 = location_df.set_index(['Postal Code'])
location_df1.head()
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476

# %% [markdown]
# Join the location dataframe with the first dataframe

# %%
result_df = pd.concat([toronto_df1, location_df1], axis=1, join='inner')
result_df.head()
# Out:
#                       Borough                                 Neighborhood  \
# Postal Code
# M3A                North York                                    Parkwoods
# M4A                North York                             Victoria Village
# M5A          Downtown Toronto                    Regent Park, Harbourfront
# M6A                North York             Lawrence Manor, Lawrence Heights
# M7A          Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#               Latitude  Longitude
# Postal Code
# M3A          43.753259 -79.329656
# M4A          43.725882 -79.315572
# M5A          43.654260 -79.360636
# M6A          43.718518 -79.464763
# M7A          43.662301 -79.389494

# %% [markdown]
# Set the index of the dataframe back to be the number

# %%
result_df.index
result_df['Postal Code'] = result_df.index


A = [i for i in range(103)]
A = pd.Index(A)

result_df = result_df.set_index(A)
result_df.head()
# Out:
#             Borough                                 Neighborhood   Latitude  \
# 0        North York                                    Parkwoods  43.753259
# 1        North York                             Victoria Village  43.725882
# 2  Downtown Toronto                    Regent Park, Harbourfront  43.654260
# 3        North York             Lawrence Manor, Lawrence Heights  43.718518
# 4  Downtown Toronto  Queen's Park, Ontario Provincial Government  43.662301
#
#    Longitude Postal Code
# 0 -79.329656         M3A
# 1 -79.315572         M4A
# 2 -79.360636         M5A
# 3 -79.464763         M6A
# 4 -79.389494         M7A

# %% [markdown]
# Reorder the columns

# %%
result_df = result_df[['Postal Code', 'Borough', 'Neighborhood', 'Latitude', 'Longitude']]
result_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# # End of Part 2

# %% [markdown]
# # Beginning of Part 3

# %% [markdown]
# Plot the map of data in each row

# %%
latitude = 43.71
longitude  = -79.38
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lon, nei, bor, code in zip(result_df['Latitude'], result_df['Longitude'], result_df['Neighborhood'], result_df['Borough'], result_df['Postal Code']):
    label = folium.Popup(code)
    folium.CircleMarker(
        [lat, lon],
        radius=4,
        popup=label,
        color='coral',
        fill=True,
        fill_color='white',
        fill_opacity=0.7
    ).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's separate the data points into 5 clusters and label them with different colour according to cluster.
#
# Create an array which tells which cluster each data point belongs to.

# %%
X = np.array([[x, y] for x, y in zip(result_df['Latitude'], result_df['Longitude'])])
kmeans = KMeans(init='k-means++', n_clusters=5, random_state=0).fit(X)
x = kmeans.labels_
x = list(x)
print(x)
# Out:
# [4, 4, 2, 0, 2, 1, 3, 4, 4, 2, 0, 1, 3, 4, 4, 2, 2, 1, 3, 4, 2, 2, 3, 4, 2, 2, 3, 0, 0, 4, 2, 2, 3, 4, 0, 4, 2, 2, 4, 0, 0, 2, 2, 2, 4, 0, 1, 4, 2, 1, 1, 3, 0, 1, 2, 0, 1, 1, 4, 0, 1, 0, 0, 1, 1, 4, 0, 0, 2, 1, 1, 4, 0, 0, 2, 2, 1, 1, 3, 2, 2, 1, 4, 2, 2, 3, 2, 2, 1, 1, 4, 2, 2, 1, 1, 3, 2, 2, 1, 2, 4, 1, 1]

# %% [markdown]
# Plot the same map but change the colour of each data point according to the cluster of each point.

# %%
latitude = 43.71
longitude  = -79.38
map_clusters1 = folium.Map(location=[latitude, longitude], zoom_start=11)

colour = ['blue', 'green', 'coral', 'yellow', 'purple', 'pink']
for lat, lon, nei, bor, code, group in zip(result_df['Latitude'], result_df['Longitude'], result_df['Neighborhood'], result_df['Borough'], result_df['Postal Code'], x):
    label = folium.Popup(code)
    folium.CircleMarker(
        [lat, lon],
        radius=4,
        popup=label,
        color=colour[group],
        fill=True,
        fill_color='white',
        fill_opacity=0.7
    ).add_to(map_clusters1)
       
map_clusters1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Please see the following picture (screenshot from the actual notebook) in case that the map cannot be loaded on Github due to trust issue

# %% [markdown]
# <img src="https://i.ibb.co/MZT2RZL/123.png">

# %% [markdown]
# <img src="https://i.ibb.co/2FdQk82/1232.png">

# %% [markdown]
# # End of Part 3
